# %% [markdown]
# # General Notebook

# %%
seed = 123
import os
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from torchsummary import summary
import random
import torch
random.seed(seed)     # python random generator
np.random.seed(seed)  # numpy random generator

torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Change the name to create or load the data and models
path = os.getcwd()
folder_data = r'Data\data_mlsp_semi'
#-------------------------------
if torch.cuda.is_available():  
    device = "cuda:0" 
else:  
    device = "cpu"  
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Data

# %%
#--------------------------------------------
# 0: Vaquita girada
# 1: Cow     2: Human 
# 3: Horse   4: Camel
# 5: Dog1    6: Dog2
idx  = 1 #! Id image
p = 40 #! porcentage of missing labels  options: [40, 60, 80, 100]
names = ['bull', 'cow', 'human', 'horse', 'camel', 'dog1', 'dog2']
name_image = names[idx]+str(p)
print(name_image)
# Out:
# cow40

# %%
#!  Pay attention to idx when we read the data 
x1 = plt.imread(os.path.join(path, folder_data, 'x{}.png'.format(idx+1)))
m, n = x1.shape
y_true = plt.imread(os.path.join(path, folder_data, 'y{}.png'.format(idx+1))).reshape(m*n, 1)
y1 =  np.load(os.path.join(path, folder_data, 'y_miss_{}.npy'.format(p)))[idx].reshape(m*n, 1)
x = torch.tensor(x1.reshape(m*n, 1), dtype=torch.float32)
y = torch.tensor(y1, dtype=torch.float32)
x = x.to(device)
y = y.to(device)

# %%
fig = plt.figure(figsize=(20, 30))  
rows = 1
columns = 3
fig.add_subplot(rows, columns, 1)
plt.imshow(x1, cmap='gray')
fig.add_subplot(rows, columns, 2)
plt.imshow(y1.reshape(m,n), cmap='gray')
fig.add_subplot(rows, columns, 3)
plt.imshow(y_true.reshape(m,n), cmap='gray')

# %% [markdown]
# ## Functions and models

# %%
from models.SVRNN import SVRNN
from models.SVRNN_2 import SVRNN_2
from models.VSL import VSL
from models.TMM import TMM
from models.TMM_2 import TMM_2
from utils.training import final_model, run_model_seq, num_param, plot_loss_epoch

# %% [markdown]
# # Models

# %%
# General Parameters (we do not change the values of these parameters during the simulations)
x_dim = 1
y_dim = 1
# Parameters for the models
learning_rate = 0.007 # ! We can change this parameter but change the information in the sheet annotation
weight_decay_ = 1e-4
n_epochs = 100
clip = 10
# Parameters for printing and saving the results
#! Change this path for your own path to save the results 
print_every = 1
save_every = 2
# general_path  = os.path.join(os.getcwd(), 'Results_save_models') #! Any
# general_path = r'C:\Users\kmorales\Desktop\3th PhD\MLSP 2023\Results_save_models' #! University
general_path = r"C:\Users\katyt\Desktop\PhD\MLSP 2023\Results_save_models" #! Home
print('Saving our model in',general_path)
# Out:
# Saving our model in C:\Users\katyt\Desktop\PhD\MLSP 2023\Results_save_models

# %% [markdown]
# ### VLS

# %%
# Dimension of latent variables
z_dim = 1
# h_dim = 48# This value is not necessary for the TMM model
# num_neurons = 20 #? == h_dim?
h_dim = 14# This value is not necessary for the TMM model
num_neurons = 41 #? == h_dim?


#--------------------------------------------
#! Change here if the model is the same but with different parameters
setting = ''# '_1' #* Change to '', '_1', '_2', etc. if the model is the same but with different parameters
#--------------------------------------------
model = VSL(x_dim, z_dim, y_dim, h_dim, num_neurons, device)

# %%
#--------------------------------------------
# Save models
#--------------------------------------------
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
print(f'{model.__class__.__name__ } has {num_param(model)} parameters to train' )
print(f'z_dim = {z_dim}, num_neurons = {num_neurons}, h_dim = {h_dim}')
data = model.__class__.__name__.casefold()+'_'+name_image+setting
path_save = os.path.join(general_path, data)
if not os.path.exists(path_save):
    os.makedirs(path_save)
print(f'Actual path to save our models for {data} is \n {path_save} ')
# Out:
# VSL has 5383 parameters to train
# z_dim = 1, num_neurons = 41, h_dim = 14
# Actual path to save our models for vsl_cow40 is
#  C:\Users\katyt\Desktop\PhD\MLSP 2023\Results_save_models\vsl_cow40

# %%
# #* Training
# #* epoch_init = 1 by default
loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every)

# %%
# #* Training
# #* epoch_init = 1 by default
# loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every)

# %%
# #* Initialization of the model in an specific epoch
model.to(device)
epoch_init = 100
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
#-----------------------------------------------------
model = final_model(model, optimizer, epoch_init, path_save, device=device)
# plot_loss_epoch(model, path_save,data, epoch_init)
#loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every, epoch_init)

# %%
y_ = model.reconstruction(x,y).cpu().detach().numpy()

# %%
# #* Reconstruction
# y_ = model.reconstruction(x,y)
# y_ = y_.cpu().detach()
y_pred_m = y_[np.where(y1 == -1)]#.numpy()
y_true_m = y_true[np.where(y1 == -1)]
error_rate = 1-accuracy_score(y_true_m, y_pred_m)
print(f'{name_image}: {model.__class__.__name__ } with  {num_param(model)} parameters \n after {epoch_init} has an error rate of {error_rate}\n folder {data}' )

# %%
# #* Reconstruction
# y_ = model.reconstruction(x,y)
# y_ = y_.cpu().detach()
y_pred_m = y_[np.where(y1 == -1)]#.numpy()
y_true_m = y_true[np.where(y1 == -1)]
error_rate = 1-accuracy_score(y_true_m, y_pred_m)
print(f'{name_image}: {model.__class__.__name__ } with  {num_param(model)} parameters \n after {epoch_init} has an error rate of {error_rate}\n folder {data}' )

# %% [markdown]
# ## TMM

# %%
# Dimension of latent variables
z_dim = 1
h_dim = None # This value is not necessary for the TMM model
num_neurons = 28 #? == h_dim?

#--------------------------------------------
#! Change here if the model is the same but with different parameters
setting = ''# '_1' #* Change to '', '_1', '_2', etc. if the model is the same but with different parameters
#--------------------------------------------
model = TMM(x_dim, z_dim, y_dim, num_neurons, device)

# %%
#--------------------------------------------
# Save models
#--------------------------------------------
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
print(f'{model.__class__.__name__ } has {num_param(model)} parameters to train' )
print(f'z_dim = {z_dim}, num_neurons = {num_neurons}, h_dim = {h_dim}')
data = model.__class__.__name__.casefold()+'_'+name_image+setting
path_save = os.path.join(general_path, data)
if not os.path.exists(path_save):
    os.makedirs(path_save)
print(f'Actual path to save our models for {data} is \n {path_save} ')

# %% [markdown]
# ### Training

# %%
#* Training
#* epoch_init = 1 by default
loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every)

# %% [markdown]
# ### Initialization from a specific epoch

# %%
# # #* Initialization of the model in an specific epoch
# model.to(device)
# epoch_init = 100
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
# #-----------------------------------------------------
# model = final_model(model, optimizer, epoch_init, path_save, device=device)
# plot_loss_epoch(model, path_save,data, epoch_init)
# #loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every, epoch_init)

# %% [markdown]
# ### Reconstruction image

# %%
# # #* Reconstruction
# y_ = model.sample(x,y)
# # y_ = model.sample(x,y).cpu()
# y_pred_m = y_[np.where(y1 == -1)].numpy()
# y_true_m = y_true[np.where(y1 == -1)]
# error_rate = 1-accuracy_score(y_true_m, y_pred_m)
# print(f'{name_image}: {model.__class__.__name__ } with  {num_param(model)} parameters \n after {epoch_init} has an error rate of {error_rate}\n folder {data}' )

# %% [markdown]
# ## SVRNN

# %%
# Dimension of latent variables
z_dim = 1
h_dim = 14 # This value is not necessary for the TMM model
num_neurons = 22 #? == h_dim?
add_loss = True
#--------------------------------------------
#! Change here if the model is the same but with different parameters
setting = "_l{}_11".format(int(add_loss))# '_1'# '_1' #* Change to '', '_1', '_2', etc. if the model is the same but with different parameters
#--------------------------------------------
model = SVRNN_2(x_dim, z_dim, h_dim, y_dim, num_neurons, device, add_loss)

# %% [markdown]
# ### Execution

# %%
#--------------------------------------------
# Save models
#--------------------------------------------
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
print(f'{model.__class__.__name__ } has {num_param(model)} parameters to train' )
print(f'z_dim = {z_dim}, num_neurons = {num_neurons}, h_dim = {h_dim}')
data = model.__class__.__name__.casefold()+'_'+name_image+setting
path_save = os.path.join(general_path, data)
if not os.path.exists(path_save):
    os.makedirs(path_save)
print(f'Actual path to save our models for {data} is \n {path_save} ')
# Out:
# SVRNN_2 has 5240 parameters to train
# z_dim = 1, num_neurons = 22, h_dim = 14
# Actual path to save our models for svrnn_2_cow40_l1_11 is
#  C:\Users\katyt\Desktop\PhD\MLSP 2023\Results_save_models\svrnn_2_cow40_l1_11

# %%
#* Training
loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every)
# Out:
# The model is saved in this path C:\Users\katyt\Desktop\PhD\MLSP 2023\Results_save_models\svrnn_2_cow40_l1_11\svrnn_2
# C:\Users\katyt\Google Drive\PhD\Simulations_semi_super\utils\training.py:46: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   nn.utils.clip_grad_norm(model.parameters(), clip)
# Loss Labeled: 2029.431641 	 Loss Unlabeled: -16321.245117
# Loss Labeled: -2498.312500 	 Loss Unlabeled: -18751.162109
# Loss Labeled: -6101.406250 	 Loss Unlabeled: -20722.986328
# Loss Labeled: -9007.222656 	 Loss Unlabeled: -22238.744141
# Loss Labeled: -11982.541016 	 Loss Unlabeled: -23759.367188
# Loss Labeled: -15483.724609 	 Loss Unlabeled: -25620.554688
# Loss Labeled: -19393.292969 	 Loss Unlabeled: -27754.966797
# Loss Labeled: -23294.855469 	 Loss Unlabeled: -29878.068359
# Loss Labeled: -26388.236328 	 Loss Unlabeled: -31518.201172
# Loss Labeled: -27822.785156 	 Loss Unlabeled: -32326.832031
# Loss Labeled: -28247.806641 	 Loss Unlabeled: -32854.375000
# Loss Labeled: -29609.570312 	 Loss Unlabeled: -34179.183594
# Loss Labeled: -32740.097656 	 Loss Unlabeled: -36615.226562
# Loss Labeled: -36625.101562 	 Loss Unlabeled: -39338.425781
# Loss Labeled: -39862.687500 	 Loss Unlabeled: -41428.535156
# Loss Labeled: -42316.250000 	 Loss Unlabeled: -42900.425781
# Loss Labeled: -44905.242188 	 Loss Unlabeled: -44407.539062
# Loss Labeled: -48251.128906 	 Loss Unlabeled: -46374.640625
# Loss Labeled: -52304.425781 	 Loss Unlabeled: -48872.480469
# Loss Labeled: -56410.425781 	 Loss Unlabeled: -51676.781250
# Loss Labeled: -59675.476562 	 Loss Unlabeled: -54227.167969
# Loss Labeled: -62331.441406 	 Loss Unlabeled: -56493.871094
# Loss Labeled: -65267.500000 	 Loss Unlabeled: -58781.210938
# Loss Labeled: -70335.484375 	 Loss Unlabeled: -62055.996094
# Loss Labeled: -75924.562500 	 Loss Unlabeled: -65073.503906
# Loss Labeled: -78372.718750 	 Loss Unlabeled: -65882.914062
# Loss Labeled: -79445.000000 	 Loss Unlabeled: -66010.984375
# Loss Labeled: -81279.078125 	 Loss Unlabeled: -66586.156250
# Loss Labeled: -81445.125000 	 Loss Unlabeled: -65788.507812
# Loss Labeled: -80202.617188 	 Loss Unlabeled: -64377.875000
# Loss Labeled: -80349.625000 	 Loss Unlabeled: -64142.085938
# Loss Labeled: -80934.882812 	 Loss Unlabeled: -64372.398438
# Loss Labeled: -83119.476562 	 Loss Unlabeled: -66076.210938
# Loss Labeled: -83639.531250 	 Loss Unlabeled: -67031.078125
# Loss Labeled: -85069.578125 	 Loss Unlabeled: -68010.726562
# Loss Labeled: -84988.054688 	 Loss Unlabeled: -67627.015625
# Loss Labeled: -84596.343750 	 Loss Unlabeled: -67241.320312
# Loss Labeled: -85674.679688 	 Loss Unlabeled: -67814.843750
# Loss Labeled: -85177.601562 	 Loss Unlabeled: -67607.023438
# Loss Labeled: -83906.703125 	 Loss Unlabeled: -66803.890625
# Loss Labeled: -85002.515625 	 Loss Unlabeled: -67111.351562
# Loss Labeled: -86288.539062 	 Loss Unlabeled: -67573.867188
# Loss Labeled: -86412.625000 	 Loss Unlabeled: -67367.468750
# Loss Labeled: -87500.156250 	 Loss Unlabeled: -67889.320312
# Loss Labeled: -87574.882812 	 Loss Unlabeled: -67773.078125
# Loss Labeled: -86857.531250 	 Loss Unlabeled: -66911.601562
# Loss Labeled: -88263.078125 	 Loss Unlabeled: -67327.632812
# Loss Labeled: -88991.078125 	 Loss Unlabeled: -67233.164062
# Loss Labeled: -87888.148438 	 Loss Unlabeled: -66290.703125
# Loss Labeled: -88333.906250 	 Loss Unlabeled: -66435.421875
# Loss Labeled: -89562.203125 	 Loss Unlabeled: -66970.156250
# Loss Labeled: -88861.085938 	 Loss Unlabeled: -66352.148438
# Loss Labeled: -89480.835938 	 Loss Unlabeled: -66462.460938
# Loss Labeled: -91228.710938 	 Loss Unlabeled: -67272.210938
# Loss Labeled: -91133.734375 	 Loss Unlabeled: -67040.890625
# Loss Labeled: -91669.843750 	 Loss Unlabeled: -67034.320312
# Loss Labeled: -92001.156250 	 Loss Unlabeled: -66873.625000
# Loss Labeled: -92006.046875 	 Loss Unlabeled: -66422.187500
# Loss Labeled: -92692.445312 	 Loss Unlabeled: -66439.390625
# Loss Labeled: -92954.015625 	 Loss Unlabeled: -66135.296875
# Loss Labeled: -93788.695312 	 Loss Unlabeled: -66183.523438
# Loss Labeled: -93729.718750 	 Loss Unlabeled: -65542.742188
# Loss Labeled: -92680.890625 	 Loss Unlabeled: -64270.683594
# Loss Labeled: -94309.757812 	 Loss Unlabeled: -64900.230469
# Loss Labeled: -96545.250000 	 Loss Unlabeled: -65780.296875
# Loss Labeled: -93085.687500 	 Loss Unlabeled: -64229.859375
# Loss Labeled: -88067.953125 	 Loss Unlabeled: -62298.343750
# Loss Labeled: -89020.234375 	 Loss Unlabeled: -62932.109375
# Loss Labeled: -94768.195312 	 Loss Unlabeled: -65269.656250
# Loss Labeled: -98074.273438 	 Loss Unlabeled: -66393.968750
# Loss Labeled: -97174.812500 	 Loss Unlabeled: -66246.796875
# Loss Labeled: -96173.148438 	 Loss Unlabeled: -66881.375000
# Loss Labeled: -95697.968750 	 Loss Unlabeled: -67182.773438
# Loss Labeled: -97213.609375 	 Loss Unlabeled: -67596.757812
# Loss Labeled: -97984.835938 	 Loss Unlabeled: -67665.539062
# Loss Labeled: -97713.515625 	 Loss Unlabeled: -67779.226562
# Loss Labeled: -97802.625000 	 Loss Unlabeled: -68175.210938
# Loss Labeled: -97220.171875 	 Loss Unlabeled: -67644.375000
# Loss Labeled: -96200.023438 	 Loss Unlabeled: -67273.335938
# Loss Labeled: -96820.109375 	 Loss Unlabeled: -68037.695312
# Loss Labeled: -97698.804688 	 Loss Unlabeled: -68741.421875
# Loss Labeled: -97043.398438 	 Loss Unlabeled: -68337.132812
# Loss Labeled: -97505.187500 	 Loss Unlabeled: -68700.445312
# Loss Labeled: -97583.351562 	 Loss Unlabeled: -68879.148438
# Loss Labeled: -97899.632812 	 Loss Unlabeled: -68896.250000
# Loss Labeled: -98475.804688 	 Loss Unlabeled: -68963.546875
# Loss Labeled: -98929.945312 	 Loss Unlabeled: -69016.796875
# Loss Labeled: -98539.578125 	 Loss Unlabeled: -68303.421875
# Loss Labeled: -98461.593750 	 Loss Unlabeled: -67701.414062
# Loss Labeled: -98901.375000 	 Loss Unlabeled: -67555.171875
# Loss Labeled: -98406.054688 	 Loss Unlabeled: -67273.476562
# Loss Labeled: -98218.140625 	 Loss Unlabeled: -67206.593750
# Loss Labeled: -99595.812500 	 Loss Unlabeled: -68373.187500
# Loss Labeled: -99862.750000 	 Loss Unlabeled: -68856.937500
# Loss Labeled: -99513.992188 	 Loss Unlabeled: -68897.562500
# Loss Labeled: -99877.671875 	 Loss Unlabeled: -69204.882812
# Loss Labeled: -100306.632812 	 Loss Unlabeled: -68986.085938
# Loss Labeled: -100797.726562 	 Loss Unlabeled: -69026.539062
# Loss Labeled: -99744.562500 	 Loss Unlabeled: -68184.054688
# Loss Labeled: -98934.820312 	 Loss Unlabeled: -67504.742188

# %%
# # #* Initialization of the model in an specific epoch
# model.to(device)
# epoch_init = 100
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_)
# #-----------------------------------------------------
# model = final_model(model, optimizer, epoch_init, path_save, device)
# plot_loss_epoch(model, path_save,data, epoch_init)
# # # loss = run_model_seq(x, y,model,optimizer,clip, path_save, n_epochs,save_every, print_every, epoch_init)

# %%
# # #* Reconstruction
# y_ = model.sample(x,y)
# y_pred_m = y_[np.where(y1 == -1)].numpy()
# y_true_m = y_true[np.where(y1 == -1)]
# error_rate = 1-accuracy_score(y_true_m, y_pred_m)
# print(f'{name_image}: {model.__class__.__name__ } with  {num_param(model)} parameters \n after {epoch_init} has an error rate of {error_rate}\n folder {data}' )

# %% [markdown]
# # Other Code
# Creation missing labels and plots

# %%
#-------------------------------
# Change the name to create or load the data and models

folder_data = r'C:\Users\kmorales\Google Drive\PhD\Simulations_semi_super\Data\data_mlsp_semi'


x_list = []
y_list = []
# y_list_40 = []
# y_list_60 = []
# y_list_80 = []
# y_list_100 = []


for img in sorted(os.listdir(folder_data)):
    if img.startswith('x'):
        x_list.append(plt.imread(os.path.join(folder_data, img)))
    if img.startswith('y') and not img.endswith('npy'):
        y = plt.imread(os.path.join(folder_data, img))
        y_list.append(y)
        # Only if we want to create the missing labels for different probabilities
#         for p in probabilities:
#             if p == 0.4:
#                 y_list_40.append(create_missing_labels(y, p))
#             elif p == 0.6:
#                 y_list_60.append(create_missing_labels(y, p))
#             elif p == 0.8:
#                 y_list_80.append(create_missing_labels(y, p))
#             elif p == 1:
#                 y_list_100.append(create_missing_labels(y, p))
        
# np.save(os.path.join(general_path, folder_data, 'y_miss_40.npy'), y_list_40)
# np.save(os.path.join(general_path, folder_data, 'y_miss_60.npy'), y_list_60)
# np.save(os.path.join(general_path, folder_data, 'y_miss_80.npy'), y_list_80)
# np.save(os.path.join(general_path, folder_data, 'y_miss_100.npy'), y_list_100)

# Load the created data 
y_list_40 = np.load(os.path.join(general_path, folder_data, 'y_miss_40.npy'))
y_list_60 = np.load(os.path.join(general_path, folder_data, 'y_miss_60.npy'))
y_list_80 = np.load(os.path.join(general_path, folder_data, 'y_miss_80.npy'))
y_list_100 = np.load(os.path.join(general_path, folder_data, 'y_miss_100.npy'))

# %%
fig = plt.figure(figsize=(20, 30))  
rows = len(x_list)
columns = 6
m, n = x_list[0].shape


for i, (x,y, y1,y2,y3, y4) in enumerate(zip(x_list, y_list, y_list_40, y_list_60, y_list_80, y_list_100)):
    print(x.shape)
    fig.add_subplot(rows, columns, columns*i+1)
    x[m-1, n-1] = -1
    plt.imshow(x, cmap='gray')
    plt.title('Image  idex {}'.format(i))
    #plt.axis('off')
    fig.add_subplot(rows, columns, columns*i+2)
    y[m-1, n-1] = -1
    plt.imshow(y, cmap='gray')
    #plt.axis('off')
    fig.add_subplot(rows, columns, columns*i+3)
    plt.imshow(y1, cmap='gray')
    #plt.axis('off')
    fig.add_subplot(rows, columns, columns*i+4)
    plt.imshow(y2, cmap='gray')
    #plt.axis('off')
    fig.add_subplot(rows, columns, columns*i+5)
    plt.imshow(y3, cmap='gray')
    #plt.axis('off')
    fig.add_subplot(rows, columns, columns*i+6)
    plt.imshow(y4, cmap='gray')

# %%
print('{} has {} parameters to train'.format(model.__class__.__name__ ,num_param(model)) )

# %%
y_ = model.sample(x,y)
image_complete = y_.clone().detach().numpy().reshape(m,n)
image_complete[m-1,n-1] = -1
image_labeled = y_list[idx].copy()
image_labeled[m-1,n-1] = -1
plt.imshow(x_list[idx])
plt.show()
plt.imshow(image_complete)
plt.show()
plt.imshow(image_labeled)
plt.show()
plt.imshow(y_list_80[idx])
plt.show()


unique, counts = np.unique(y_true, return_counts=True)
print(unique, counts)
unique, counts = np.unique(y_pred, return_counts=True)
print(unique, counts)
